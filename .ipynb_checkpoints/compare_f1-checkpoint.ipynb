# %%
import os
import pandas as pd
import numpy as np
import timeit

import matplotlib.pyplot as plt
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, normalize
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

import seaborn as sns


def train_single_model(file_name):
    path = './'
    file_name = file_name
    file = os.path.join(path, file_name)
    print(file)
    # read data
    df = pd.read_csv(file)
    feature_names = ['Age','Tenure','PSYTE_Segment','Total_score','Trnx_count','num_products', 'Churn_risk']
    #feature_names = ['Age','Tenure','PSYTE_Segment','Trnx_count','num_products', 'Churn_risk']

    selected_df = df[feature_names].dropna()

    # binarize
    selected_df['Churn_risk'][selected_df['Churn_risk'] == 'Medium'] = 'High'  
    #selected_df = selected_df.drop(selected_df[selected_df['Churn_risk'] == 'Medium'].index) 
    
    # Data normalization
    X_data = selected_df.drop(columns=['PSYTE_Segment','Churn_risk'])
    X_target = selected_df[['PSYTE_Segment','Churn_risk']]
    X_data_b = pd.DataFrame(normalize(X_data, norm='l2', axis=1, copy=True, return_norm=False),columns=X_data.columns)
    X = pd.concat([X_data_b, X_target], axis=1)
    X = X.dropna()
    
    X['Churn_risk'] = X.Churn_risk.astype("category").cat.codes
    client_data = X.dropna()

    #for rat in range(100,1,-1):
    #data_s = data.sample(frac=0.01)
    #data_r = data_s.sample(frac=rat/100.)
    client_data = client_data.sample(frac=1)
    X = client_data.drop(columns=['Churn_risk','PSYTE_Segment'])
    y = client_data['Churn_risk']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42) 
    
    X = pd.concat([X_train, y_train], axis=1)
    low = X[X.Churn_risk==1]
    high = X[X.Churn_risk==0]
    #medium = X[X.Churn_risk==2]
    
    X.Churn_risk.value_counts()

    low_downsampled = resample(low,
                                replace = True, # sample without replacement
                                n_samples = len(high), # match minority n
                                random_state = 27) # reproducible results

    # combine minority and downsampled majority
    downsampled = pd.concat([low_downsampled, high])

    # checking counts
    print('Labels counts after balancing.')
    print(downsampled.Churn_risk.value_counts())

    X_train = downsampled.drop('Churn_risk', axis=1)
    y_train = downsampled.Churn_risk
    
    print(f'Traing size {np.shape(y_train)}')
    print(f'Testing size {np.shape(y_test)}')

    LR = LogisticRegression()
    LRparam_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'tol': [1e-6, 1e-5, 1e-4, 1e-2, 1e-1, 1],
    'penalty': ['l2'],
    'max_iter': list(range(100,800,100)),
    'solver': ['newton-cg', 'lbfgs', 'liblinear'] #'sag', 'saga'
    }

    clf = GridSearchCV(LR, param_grid=LRparam_grid, refit = True, verbose = 3, cv=10, scoring='f1')

    # fitting the model for grid search 
    clf.fit(X_train , y_train)
    print('best parameters', clf.best_params_)
    # summarize
    print('Mean f1: %.3f' % clf.best_score_)
    print('Best parameters Config: %s' % clf.best_params_)

    #clf = LogisticRegressionCV( cv=10, max_iter=100, tol=1e-2, n_jobs=-1, solver='liblinear', scoring='f1')
    #clf = LogisticRegressionCV( cv=10, max_iter=100000, tol=1e-6, n_jobs=-1, solver='lbfgs')

    #clf.fit(X_train, y_train)

    #spit the test data into 2 set
    X_combined = pd.concat([X_test, y_test], axis=1)
    X_test_b = np.array_split(X_combined.sample(frac=1), 1)
    #a = pd.DataFrame(X_test_b[0])

    # train    
    y_pred3=clf.predict(X_train)
    f12 = round(np.max(f1_score(y_train, y_pred3, average=None))*100, 2)
    print(f'The performance of the model: {np.round(clf.score(X_test, y_test)*100,2)}')

    # folding
    #spit the test data into 2 set
    X_combined = pd.concat([X_test, y_test], axis=1)
    X_test_b = np.array_split(X_combined.sample(frac=1), 1)

    for k, test in enumerate(X_test_b):
        y_pred_1=clf.predict(test.drop(columns='Churn_risk'))
        f1 = round(np.max(f1_score(test['Churn_risk'], y_pred_1, average=None))*100, 2)
        print(f'f1 for {k}th-fold test data', f1)

    '''
    #f1_ave = round(f1_score(y_test, y_pred, average='weighted')*100, 2)
    #accuracy = round(accuracy_score(y_test, y_pred)*100,2)
    report1 = classification_report(X_test_b[0]['Churn_risk'], y_pred_1, zero_division=0)
    print(report1)
    report2 = classification_report(X_test_b[1]['Churn_risk'], y_pred_2, zero_division=0)
    print(report2)
    
    print(classification_report(y_train, y_pred3, zero_division=0))
    print(confusion_matrix(X_test_b[0]['Churn_risk'], y_pred_1))
    print(confusion_matrix(X_test_b[1]['Churn_risk'], y_pred_2))
    print('f1 for test 1 data', f1)
    print('f1 for test 2 data', f2)
    print('f1 for train data', f12)

    '''
    fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(16, 14))
    idx_feature = 0  

    _X = pd.concat([X_train, y_train], axis=1).reset_index().drop(columns='index')
    print(np.shape(_X))
    for i in range(ax.shape[0]):
        for j in range(0, ax.shape[1]):
            try:  
                feature = _X.columns[idx_feature]    
                plot = sns.histplot(_X, 
                                hue = 'Churn_risk', 
                                x = feature, 
                                multiple = 'stack',
                                binwidth = 1,
                                bins=5,
                                stat = 'count',
                                ax=ax[i][j])
                #plt.show()
                idx_feature +=1
            except IndexError:
                pass
            plt.savefig(f'feature_distribution_train.png')

    _Y = pd.concat([X_test, y_test], axis=1).reset_index().drop(columns='index')

    fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(16, 14))
    idx_feature = 0  
    for i in range(ax.shape[0]):
        for j in range(0, ax.shape[1]):
            try:  
                feature = _Y.columns[idx_feature]    
                plot = sns.histplot(_Y, 
                                hue = 'Churn_risk', 
                                x = feature, 
                                multiple = 'stack',
                                binwidth = 1,
                                bins=5,
                                stat = 'count',
                                ax=ax[i][j])
                #plt.show()
                idx_feature +=1
            except IndexError:
                pass
            plt.savefig(f'feature_distribution_test.png')
            
train_single_model('churnsimulateddata.csv')
# Out:
# ./churnsimulateddata.csv
# /var/folders/7s/lxjghsr57nscy448l9t3l2800000gq/T/ipykernel_31340/1971029694.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['Churn_risk'][selected_df['Churn_risk'] == 'Medium'] = 'High'
# Labels counts after balancing.
# 1    174486
# 0    174486
# Name: Churn_risk, dtype: int64
# Traing size (348972,)
# Testing size (282678,)
# Fitting 10 folds for each of 756 candidates, totalling 7560 fits
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   1.6s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.772 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.779 total time=   1.7s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   1.6s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.6s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.772 total time=   0.6s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.779 total time=   1.6s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.5s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.772 total time=   0.5s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.779 total time=   0.5s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.4s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.772 total time=   0.4s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.779 total time=   0.5s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.01;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.778 total time=   0.4s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.772 total time=   0.4s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.779 total time=   0.4s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.777 total time=   0.4s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.780 total time=   0.4s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=0.1;, score=0.778 total time=   0.4s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg, tol=1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.779 total time=   0.4s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.778 total time=   0.4s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.4s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.777 total time=   0.4s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.01;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.4s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=0.1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs, tol=1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.1s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.773 total time=   0.1s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.780 total time=   0.1s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.782 total time=   0.1s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 1/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 2/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 3/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.777 total time=   0.1s
# [CV 4/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.771 total time=   0.1s
# [CV 5/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.778 total time=   0.1s
# [CV 6/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 7/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.778 total time=   0.1s
# [CV 8/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.780 total time=   0.1s
# [CV 9/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 10/10] END C=0.001, max_iter=100, penalty=l2, solver=liblinear, tol=1;, score=0.777 total time=   0.1s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   1.6s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.772 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.779 total time=   1.6s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   1.6s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.772 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.779 total time=   1.6s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.772 total time=   0.5s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.779 total time=   0.5s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.772 total time=   0.5s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.779 total time=   0.4s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.01;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.777 total time=   0.4s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.778 total time=   0.4s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.772 total time=   0.4s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.779 total time=   0.4s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.777 total time=   0.4s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.780 total time=   0.4s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.776 total time=   0.4s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=0.1;, score=0.778 total time=   0.4s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg, tol=1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.777 total time=   0.4s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.01;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.778 total time=   0.4s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=0.1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.777 total time=   0.3s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.778 total time=   0.3s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.772 total time=   0.3s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.779 total time=   0.3s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.777 total time=   0.3s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.780 total time=   0.3s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.776 total time=   0.3s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs, tol=1;, score=0.778 total time=   0.3s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-06;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1e-05;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.0001;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.2s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.2s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.773 total time=   0.2s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.780 total time=   0.2s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.778 total time=   0.2s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.782 total time=   0.2s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.777 total time=   0.2s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.01;, score=0.779 total time=   0.2s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.773 total time=   0.1s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.780 total time=   0.1s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.782 total time=   0.1s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.778 total time=   0.1s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=0.1;, score=0.779 total time=   0.1s
# [CV 1/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 2/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 3/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.777 total time=   0.1s
# [CV 4/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.771 total time=   0.1s
# [CV 5/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.778 total time=   0.1s
# [CV 6/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 7/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.778 total time=   0.1s
# [CV 8/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.780 total time=   0.1s
# [CV 9/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.776 total time=   0.1s
# [CV 10/10] END C=0.001, max_iter=200, penalty=l2, solver=liblinear, tol=1;, score=0.777 total time=   0.1s
# [CV 1/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   1.7s
# [CV 3/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.772 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.779 total time=   1.7s
# [CV 6/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.780 total time=   0.6s
# [CV 9/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-06;, score=0.778 total time=   0.6s
# [CV 1/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 2/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   1.6s
# [CV 3/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.772 total time=   0.5s
# /opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [CV 5/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.779 total time=   1.6s
# [CV 6/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=1e-05;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.5s
# [CV 2/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.772 total time=   0.5s
# [CV 5/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.779 total time=   0.5s
# [CV 6/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 7/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.777 total time=   0.5s
# [CV 8/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.780 total time=   0.5s
# [CV 9/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.776 total time=   0.5s
# [CV 10/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.0001;, score=0.778 total time=   0.5s
# [CV 1/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.5s
# [CV 2/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# [CV 3/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.778 total time=   0.5s
# [CV 4/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.772 total time=   0.5s
# [CV 5/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.779 total time=   0.7s
# [CV 6/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   1.0s
# [CV 7/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.777 total time=   0.6s
# [CV 8/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.780 total time=   0.6s
# [CV 9/10] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg, tol=0.01;, score=0.776 total time=   0.5s
# ...
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.792 total time=   0.4s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.796 total time=   0.3s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.795 total time=   0.4s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.797 total time=   0.4s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.01;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.796 total time=   0.4s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.795 total time=   0.4s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.796 total time=   0.4s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.797 total time=   0.4s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=0.1;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.794 total time=   0.4s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.792 total time=   0.3s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.796 total time=   0.3s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.796 total time=   0.3s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.795 total time=   0.3s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.796 total time=   0.3s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.797 total time=   0.4s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.794 total time=   0.3s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=newton-cg, tol=1;, score=0.796 total time=   0.3s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-06;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1e-05;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.796 total time=   0.4s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.0001;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.01;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=0.1;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.794 total time=   0.5s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.792 total time=   0.5s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.796 total time=   0.5s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.791 total time=   0.5s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.796 total time=   0.5s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.795 total time=   0.5s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.796 total time=   0.5s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.797 total time=   0.5s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.794 total time=   0.5s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=lbfgs, tol=1;, score=0.796 total time=   0.5s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.794 total time=   0.3s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.792 total time=   0.3s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.796 total time=   0.3s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.796 total time=   0.3s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.795 total time=   0.3s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.796 total time=   0.3s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.797 total time=   0.3s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.794 total time=   0.3s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-06;, score=0.796 total time=   0.3s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.794 total time=   0.3s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.792 total time=   0.3s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.796 total time=   0.3s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.796 total time=   0.3s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.795 total time=   0.3s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.796 total time=   0.3s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.797 total time=   0.3s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.794 total time=   0.3s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1e-05;, score=0.796 total time=   0.3s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.794 total time=   0.3s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.792 total time=   0.3s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.796 total time=   0.3s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.791 total time=   0.3s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.796 total time=   0.3s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.795 total time=   0.3s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.796 total time=   0.3s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.797 total time=   0.3s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.794 total time=   0.3s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.0001;, score=0.796 total time=   0.3s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.794 total time=   0.2s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.792 total time=   0.2s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.796 total time=   0.2s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.791 total time=   0.2s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.796 total time=   0.2s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.795 total time=   0.2s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.796 total time=   0.2s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.797 total time=   0.2s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.794 total time=   0.2s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.01;, score=0.795 total time=   0.2s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.788 total time=   0.2s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.786 total time=   0.2s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.790 total time=   0.2s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.785 total time=   0.2s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.790 total time=   0.2s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.788 total time=   0.2s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.789 total time=   0.2s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.791 total time=   0.2s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.788 total time=   0.2s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=0.1;, score=0.788 total time=   0.2s
# [CV 1/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.784 total time=   0.1s
# [CV 2/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.783 total time=   0.1s
# [CV 3/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.786 total time=   0.1s
# [CV 4/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.780 total time=   0.1s
# [CV 5/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.785 total time=   0.1s
# [CV 6/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.784 total time=   0.1s
# [CV 7/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.784 total time=   0.1s
# [CV 8/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.787 total time=   0.1s
# [CV 9/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.781 total time=   0.1s
# [CV 10/10] END C=100, max_iter=700, penalty=l2, solver=liblinear, tol=1;, score=0.784 total time=   0.1s
# best parameters {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear', 'tol': 1e-05}
# Mean f1: 0.795
# Best parameters Config: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear', 'tol': 1e-05}
# The performance of the model: 82.19
# f1 for 0th-fold test data 82.19
# (348972, 6)

# %%
file='churnsimulateddata.csv'
df = pd.read_csv(file)
feature_names = ['Age','Tenure','PSYTE_Segment','Total_score','Trnx_count','num_products', 'Churn_risk']

# %%
print(df['PSYTE_Segment'].value_counts())  12, 8, 25, 57
# Out:
# 12    113187
# 8      75713
# 25     61872
# 57     35158
# 38     26657
# 21     19981
# 33     19031
# 10     18940
# 17     18629
# 4      18289
# 7      16530
# 30     16481
# 52     16469
# 18     15996
# 41     15227
# 3      14358
# 22     13054
# 5      12998
# 6      12612
# 43     11773
# 27     11296
# 16      9810
# 54      9511
# 26      8673
# 31      8585
# 15      7940
# 24      7827
# 32      7749
# 29      6528
# 47      6440
# 35      6290
# 53      6206
# 13      4856
# 50      4622
# 11      4616
# 42      4555
# 2       4228
# 40      3987
# 1       3848
# 14      3686
# 36      3642
# 55      3436
# 19      2991
# 44      2927
# 48      1546
# 37      1129
# 45      1019
# 23       999
# 56       885
# 9        843
# 20       745
# 28       724
# 39       534
# 49       466
# 34       393
# 51       149
# 46        57
# Name: PSYTE_Segment, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt 

with open('output/f1_parameters_unlearn_big2.npy', 'rb') as f:
    f1_parameters_unlearn_big = np.load(f)
with open('output/f1_parameters_local2.npy', 'rb') as f:
    f1_parameters_local = np.load(f)
with open('output/f1_parameters_unlearn_small2.npy', 'rb') as f:
    f1_parameters_unlearn_small = np.load(f)
with open('output/f1_parameters_preunlearn_global2.npy', 'rb') as f:
    f1_parameters_preunlearn_global = np.load(f)
    
data = [ f1_parameters_preunlearn_global, f1_parameters_local, f1_parameters_unlearn_small[0],f1_parameters_unlearn_big[0]]
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
#ax1.set_title('Comparing between preunlearn, unlearn 5 big clients, and unlearn 15 small clients models')
ax1.boxplot(data)
ax1.set_xticklabels(['pre-unlearn Global', 'Local',  'Unlearn 15 small clients','Unlearn 5 big clients'], fontsize=18)
ax1.set_ylabel('F1-score (%)', fontsize=18)
ax1.set_xlabel('Models', fontsize=18)
plt.yticks(fontsize=16)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

with open('output/f1_parameters_unlearn_big.npy', 'rb') as f:
    f1_parameters_unlearn_big = np.load(f)
with open('output/f1_parameters_local.npy', 'rb') as f:
    f1_parameters_local = np.load(f)
with open('output/f1_parameters_unlearn_small.npy', 'rb') as f:
    f1_parameters_unlearn_small = np.load(f)
with open('output/f1_parameters_preunlearn_global.npy', 'rb') as f:
    f1_parameters_preunlearn_global = np.load(f)
    
data = [ f1_parameters_preunlearn_global, f1_parameters_local, (np.mean(f1_parameters_unlearn_small, axis=0)),(np.mean(f1_parameters_unlearn_big, axis=0))]
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
#ax1.set_title('Comparing between preunlearn, unlearn 5 big clients, and unlearn 15 small clients models')
ax1.boxplot(data)
ax1.set_xticklabels(['Global', 'Local',  'Unlearn 15 small clients','Unlearn 5 big clients'], fontsize=18)
ax1.set_ylabel('F1-score (%)', fontsize=18)
ax1.set_xlabel('Models', fontsize=20)
plt.yticks(fontsize=16)


plt.show()

# %%
print(np.mean(f1_parameters_unlearn_big, axis=0))
# Out:
# [79.85960784 79.88901961 83.38901961 84.21568627 83.42313725 83.84235294
#  85.81823529 84.72803922 77.31607843 82.85313725 80.94588235 83.15078431
#  81.66156863 82.05666667 82.06882353 81.94117647 82.04862745 80.77509804
#  80.70196078 76.24941176 80.56882353 82.84921569 73.6545098  81.86647059
#  83.30843137 81.12098039 80.97568627 78.96705882 84.3727451  83.57843137
#  83.04666667 82.00137255 84.98019608 65.4545098  80.3654902  78.85980392
#  75.35980392 80.29039216 72.0445098  78.57745098 82.02784314 79.74803922
#  78.81372549 87.04058824 83.68882353 76.48882353 73.79823529 80.68490196
#  55.87803922 59.41254902 77.8745098 ]
